# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from reusable import label_Encoder,oneHot_encoder, cleaning, binning, flag, bmi_category

# %%
health = pd.read_csv('insurance.csv')

df = pd.DataFrame(health)

df = label_Encoder(df)
df = oneHot_encoder(df)
df = cleaning(df)
df = binning(df)
df = flag(df)
df = bmi_category(df)
df.sample(20)
# Out:
#       age  sex     bmi  children  smoker      charges  region_northwest  \
# 98     56    1  19.950         0       1  22412.64850                 0
# 222    32    1  30.800         3       0   5253.52400                 0
# 984    20    1  30.115         5       0   4915.05985                 0
# 1098   52    0  30.875         0       0  23045.56616                 0
# 343    63    1  36.765         0       0  13981.85035                 0
# 1232   54    0  24.605         3       0  12479.70895                 1
# 583    32    0  23.650         1       0  17626.23951                 0
# 349    19    1  27.835         0       0   1635.73365                 1
# 1186   20    1  35.625         3       1  37465.34375                 1
# 1119   30    0  19.950         3       0   5693.43050                 1
# 1031   55    0  35.200         0       1  44423.80300                 0
# 182    22    1  19.950         3       0   4005.42250                 0
# ...

# %%
df.isnull().sum()
# Out:
# age                 0
# sex                 0
# bmi                 0
# children            0
# smoker              0
# charges             0
# region_northwest    0
# region_southeast    0
# region_southwest    0
# high_risks          0
# obese               0
# overweight          0
# underweight         0
# dtype: int64

# %%
sns.heatmap(data=df.drop(columns=['region_northwest','region_southwest','region_southeast','sex','overweight','underweight','children','age']).corr(), annot=True, cmap='coolwarm')
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=df, x=df['charges'],bins = 23)
plt.show()

# %%
sns.boxplot(data=df, x=df['high_risks'],y=df['charges'])
plt.xticks([0,1],labels=['less_risk','more_risk'])
plt.title("understanding patient risk of increasing bmi")
plt.show()

# %%
# fig, axes = plt.subplots(2,2, figsize=(13,8))
# sns.scatterplot(data=df, x=df['bmi'],y=df['charges'],ax=axes[0,0])
# sns.scatterplot(data=df, x=df['bmi'],y=df['obese'],ax=axes[0,1])
# sns.scatterplot(data=df, x=df['charges'],y=df['high_risks'],ax=axes[1,0])
# sns.scatterplot(data=df, x=df['charges'],y=df['smoker'],ax=axes[1,1])

sns.scatterplot(data=df,x=df['bmi'],y=df['charges'])
plt.show()
