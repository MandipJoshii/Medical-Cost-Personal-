# %%
import pandas as pd

health = pd.read_csv('insurance.csv')

df = pd.DataFrame(health)

# %% [markdown]
# ### 1. how does the data looks like

# %%
print(df.sample(20))
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1307   32    male  28.120         4    yes  northwest  21472.47880
# 15     19    male  24.600         1     no  southwest   1837.23700
# 1054   27  female  21.470         0     no  northwest   3353.47030
# 301    53  female  22.610         3    yes  northeast  24873.38490
# 445    45  female  33.100         0     no  southwest   7345.08400
# 739    29    male  35.500         2    yes  southwest  44585.45587
# 380    27  female  17.955         2    yes  northeast  15006.57945
# 269    49    male  25.840         1     no  northeast   9282.48060
# 943    19    male  22.610         0     no  northwest   1628.47090
# 1287   36  female  25.900         1     no  southwest   5472.44900
# 699    23  female  39.270         2     no  southeast   3500.61230
# 1207   36    male  33.400         2    yes  southwest  38415.47400
# 268    45    male  30.200         1     no  southwest   7441.05300
# ...

# %% [markdown]
# ### 2. all common data types in csv

# %%
print(df.info())

#print(df.dtypes) -> just shows dtypes but not non-null counts and columns and index and memory usages
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB
# None

# %% [markdown]
# ### 3. common stastical imputation

# %%
print(df.describe())
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %% [markdown]
# ### 4. null values

# %%
print(df.isnull().sum())
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# ### 5. total duplicated value

# %%
print(df.duplicated().sum())
# Out:
# 1

# %% [markdown]
# ### 6. how is the dataset

# %%
print(df.shape)

print(df.columns)
# Out:
# (1338, 7)
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object
